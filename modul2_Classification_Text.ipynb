# %%
import pandas as pd
import numpy as np
import re
import string
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
train_data = pd.read_csv("D:\\UAJY\\UAJYsem6\\Pengelolahan Bahasa Alami\\Praktikum2\\modul2_Classification_Text\\data\\train_preprocess.csv")
val_data = pd.read_csv("D:\\UAJY\\UAJYsem6\\Pengelolahan Bahasa Alami\\Praktikum2\\modul2_Classification_Text\\data\\valid_preprocess.csv")
test_data = pd.read_csv("D:\\UAJY\\UAJYsem6\\Pengelolahan Bahasa Alami\\Praktikum2\\modul2_Classification_Text\\data\\test_preprocess.csv")


print('Train Data:', train_data.shape)
print('Validation Data:', val_data.shape)
print('Test Data:', test_data.shape)
# Out:
# Train Data: (810, 7)
# Validation Data: (90, 7)
# Test Data: (180, 7)

# %%
train_data.head()
# Out:
#                                             sentence      fuel   machine  \
# 0  Saya memakai Honda Jazz GK5 tahun 2014 ( perta...   neutral   neutral
# 1  Avanza kenapa jadi boros bensin begini dah ah....  negative   neutral
# 2  saran ku dan pengalaman ku , mending beli mobi...  positive  positive
# 3  Dari segi harga juga pajero lebih mahal 30 jut...   neutral   neutral
# 4                     Kalo menurut gw enak pajero si   neutral   neutral
#
#      others     part     price  service
# 0  positive  neutral   neutral  neutral
# 1   neutral  neutral   neutral  neutral
# 2   neutral  neutral   neutral  neutral
# 3   neutral  neutral  positive  neutral
# 4  positive  neutral   neutral  neutral

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = text.strip()
    return text

train_data['clean_text'] = train_data['sentence'].apply(clean_text)
val_data['clean_text'] = val_data['sentence'].apply(clean_text)
test_data['clean_text'] = test_data['sentence'].apply(clean_text)

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, KFold
import numpy as np

vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(train_data['clean_text'])
X_val = vectorizer.transform(val_data['clean_text'])
X_test = vectorizer.transform(test_data['clean_text'])

y_train = train_data['fuel']
y_val = val_data['fuel']
y_test = test_data['fuel']

param_grids = {
    'SVM': {
        'model': SVC(),
        'params': {
            'kernel': ['linear', 'rbf'],
            'C': [0.1, 1, 10]
        }
    },
    'KNN': {
        'model': KNeighborsClassifier(),
        'params': {
            'n_neighbors': [3, 5, 7],
            'weights': ['uniform', 'distance']
        }
    },
    'NB': {
        'model': MultinomialNB(),
        'params': {
            'alpha': [0.1, 0.5, 1.0]
        }
    }
}

kf = KFold(n_splits=5, shuffle=True, random_state=42)

best_models = {}
results = {}

for model_name, config in param_grids.items():
    print(f"Running GridSearchCV for {model_name}...")

    grid = GridSearchCV(config['model'], config['params'], cv=kf, scoring='accuracy')

    grid.fit(X_train, y_train)

    best_models[model_name] = grid.best_estimator_
    results[model_name] = grid.best_score_

    print(f"Best Params for {model_name}: {grid.best_params_}")
    print(f"Best Cross-Validation Accuracy: {grid.best_score_:.4f}\n")
# Out:
# Running GridSearchCV for SVM...
# Best Params for SVM: {'C': 10, 'kernel': 'linear'}
# Best Cross-Validation Accuracy: 0.9654
#
# Running GridSearchCV for KNN...
# Best Params for KNN: {'n_neighbors': 7, 'weights': 'uniform'}
# Best Cross-Validation Accuracy: 0.8852
#
# Running GridSearchCV for NB...
# Best Params for NB: {'alpha': 0.1}
# Best Cross-Validation Accuracy: 0.8852

# %%
label = ['negative', 'neutral', 'positive']
plt.figure(figsize=(10, 6))
plt.bar(results.keys(), results.values())
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Model Accuracy Comparison')
plt.show()

for model_name, model in best_models.items():
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    print(f'{model_name} Accurary on Test Set: {accuracy_score(y_test, y_pred):.4f}')

    print(f'{model_name} Classification Report:')
    print(classification_report(y_test, y_pred))

    plt.figure(figsize=(6, 4))
    sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, 
                fmt='d', cmap='Blues', xticklabels=label, yticklabels=label)
    plt.title(f'{model_name} Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
# Out:
# SVM Accurary on Test Set: 0.9611
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.90      0.90        10
#      neutral       0.98      0.99      0.98       149
#     positive       0.85      0.81      0.83        21
#
#     accuracy                           0.96       180
#    macro avg       0.91      0.90      0.90       180
# weighted avg       0.96      0.96      0.96       180
# KNN Accurary on Test Set: 0.9111
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.70      0.82        10
#      neutral       0.92      0.99      0.95       149
#     positive       0.75      0.43      0.55        21
#
#     accuracy                           0.91       180
#    macro avg       0.89      0.71      0.77       180
# weighted avg       0.90      0.91      0.90       180
# NB Accurary on Test Set: 0.8889
# NB Classification Report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.10      0.18        10
#      neutral       0.92      0.99      0.95       149
#     positive       0.61      0.52      0.56        21
#
#     accuracy                           0.89       180
#    macro avg       0.84      0.54      0.57       180
# weighted avg       0.89      0.89      0.87       180

# %%
best_model = best_models['SVM']
best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)
test_data['predicted'] = y_pred
test_data
# Out:
#                                               sentence      fuel  machine  \
# 0    Terios paling gagah . Apalagi warna merah meta...   neutral  neutral
# 1    gue pakai mobilio . menurut gue , bener fun to...   neutral  neutral
# 2    ya walaupun memiliki desain sporty kalau tingk...   neutral  neutral
# 3              Xpander laku keras di pasar Indonesia .   neutral  neutral
# 4      Kalau mau segala enak pakai Avanza saja , mas .   neutral  neutral
# ..                                                 ...       ...      ...
# 175  kecewa sama bengkel suzuki bendan, garapan eng...   neutral  neutral
# 176          Formo baris kedua, kursinya jelek banget.   neutral  neutral
# 177  Setahu saya Suzuki Splash tidak dilengkapi den...   neutral  neutral
# 178  kalo dari eksterior nya saya lebih suka brio d...   neutral  neutral
# 179              Jazz irit bbm jadi irit kantong juga.  positive  neutral
#
#        others      part    price   service  \
# 0    positive  positive  neutral   neutral
# 1    positive   neutral  neutral   neutral
# 2    negative  positive  neutral   neutral
# 3    positive   neutral  neutral   neutral
# 4    positive   neutral  neutral   neutral
# ..        ...       ...      ...       ...
# 175   neutral   neutral  neutral  negative
# 176   neutral  negative  neutral   neutral
# 177   neutral  negative  neutral   neutral
# 178   neutral  negative  neutral   neutral
# 179   neutral   neutral  neutral   neutral
#
#                                             clean_text predicted
# 0     terios paling gagah  apalagi warna merah metalic   neutral
# 1    gue pakai mobilio  menurut gue  bener fun to d...   neutral
# 2    ya walaupun memiliki desain sporty kalau tingk...   neutral
# 3                xpander laku keras di pasar indonesia   neutral
# 4         kalau mau segala enak pakai avanza saja  mas   neutral
# ..                                                 ...       ...
# 175  kecewa sama bengkel suzuki bendan garapan engg...   neutral
# 176            formo baris kedua kursinya jelek banget   neutral
# 177  setahu saya suzuki splash tidak dilengkapi den...   neutral
# 178  kalo dari eksterior nya saya lebih suka brio d...   neutral
# 179               jazz irit bbm jadi irit kantong juga  positive
#
# [180 rows x 9 columns]

# %%
correct = test_data[test_data['fuel'] == test_data['predicted']]
incorrect = test_data[test_data['fuel'] != test_data['predicted']]
print(f"Correct Predictions: {len(correct)}")
print(f"Incorrect Predictions: {len(incorrect)}")
# Out:
# Correct Predictions: 173
# Incorrect Predictions: 7

# %% [markdown]
# PART 2: MULTI-LABEL CLASSIFICATION

# %%
from skmultilearn.problem_transform import BinaryRelevance
from sklearn.metrics import multilabel_confusion_matrix

# %%
labels = ['fuel', 'machine', 'others', 'part', 'price', 'service']

train_encoded = pd.get_dummies(train_data, columns=labels, dtype=int)
val_encoded = pd.get_dummies(val_data, columns=labels, dtype=int)
test_encoded = pd.get_dummies(test_data, columns=labels, dtype=int)

# %%
train_encoded.head()
# Out:
#                                             sentence  \
# 0  Saya memakai Honda Jazz GK5 tahun 2014 ( perta...
# 1  Avanza kenapa jadi boros bensin begini dah ah....
# 2  saran ku dan pengalaman ku , mending beli mobi...
# 3  Dari segi harga juga pajero lebih mahal 30 jut...
# 4                     Kalo menurut gw enak pajero si
#
#                                           clean_text  fuel_negative  \
# 0  saya memakai honda jazz gk tahun   pertama mel...              0
# 1  avanza kenapa jadi boros bensin begini dah ah ...              1
# 2  saran ku dan pengalaman ku  mending beli mobil...              0
# 3  dari segi harga juga pajero lebih mahal  jutaa...              0
# 4                     kalo menurut gw enak pajero si              0
#
#    fuel_neutral  fuel_positive  machine_negative  machine_neutral  \
# 0             1              0                 0                1
# 1             0              0                 0                1
# 2             0              1                 0                0
# 3             1              0                 0                1
# 4             1              0                 0                1
#
#    machine_positive  others_negative  others_neutral  others_positive  \
# 0                 0                0               0                1
# 1                 0                0               1                0
# 2                 1                0               1                0
# 3                 0                0               1                0
# 4                 0                0               0                1
#
#    part_negative  part_neutral  part_positive  price_negative  price_neutral  \
# 0              0             1              0               0              1
# 1              0             1              0               0              1
# 2              0             1              0               0              1
# 3              0             1              0               0              0
# 4              0             1              0               0              1
#
#    price_positive  service_negative  service_neutral  service_positive
# 0               0                 0                1                 0
# 1               0                 0                1                 0
# 2               0                 0                1                 0
# 3               1                 0                1                 0
# 4               0                 0                1                 0

# %%
label_colums = ['fuel_negative', 'fuel_neutral', 'machine_negative', 'machine_neutral', 'machine_positive']

y_train_multi = train_encoded[label_colums]
y_val_multi = val_encoded[label_colums]
y_test_multi = test_encoded[label_colums]

# %%
import os
os.environ["OPENBLAS_NUM_THREADS"] = "1"

from sklearn.model_selection import KFold, cross_val_score
from skmultilearn.problem_transform import BinaryRelevance
from sklearn.multiclass import OneVsOneClassifier
import numpy as np

multi_kf = KFold(n_splits=5, shuffle=True, random_state=42)
result = {}

models = {"SVM": SVC(), "KNN": KNeighborsClassifier(), "NB": MultinomialNB()}

for model_name, model in models.items():
    wrapped_model = BinaryRelevance(model)

    scores = cross_val_score(
        wrapped_model,
        X_train,
        y_train_multi,
        cv=multi_kf,
        scoring="accuracy",
        n_jobs=-1,
    )

    result[model_name] = scores
    print(
        f"{model_name} - Cross-Validation Accuracy: {np.mean(scores):.4f} ± {np.std(scores):.4f}"
    )

    wrapped_model.fit(X_train, y_train_multi)

    y_pred_multi = wrapped_model.predict(X_test)

    accuracy = accuracy_score(y_test_multi, y_pred_multi)
    print(f"{model_name} Final Accuracy:", accuracy)

    print(f"{model_name} Classification Report:")
    print(
        classification_report(
            y_test_multi, y_pred_multi, target_names=label_colums, zero_division=1
        )
    )

    print(f"{model_name} Confusion Matrix:")
    mcm = multilabel_confusion_matrix(y_test_multi, y_pred_multi)
    rows, cols = 2, 3
    fig, axes = plt.subplots(
        rows, cols, figsize=(cols * 4, rows * 4)
    )

    axes = axes.flatten()

    for i, (ax, label) in enumerate(zip(axes, label_colums)):
        sns.heatmap(mcm[i], annot=True, fmt="d", cmap="Blues", ax=ax)
        ax.set_title(f"Confusion Matrix for {label}")
        ax.set_xlabel("Predicted")
        ax.set_ylabel("True")

    for j in range(len(label_colums), rows * cols):
        fig.delaxes(axes[j])
    plt.tight_layout()
    plt.show()
# Out:
# SVM - Cross-Validation Accuracy: nan ± nan
# SVM Final Accuracy: 0.75
# SVM Classification Report:
#                   precision    recall  f1-score   support
#
#    fuel_negative       1.00      0.00      0.00        10
#     fuel_neutral       0.95      1.00      0.97       149
# machine_negative       1.00      0.00      0.00        14
#  machine_neutral       0.91      1.00      0.95       137
# machine_positive       0.83      0.34      0.49        29
#
#        micro avg       0.93      0.87      0.90       339
#        macro avg       0.94      0.47      0.48       339
#     weighted avg       0.93      0.87      0.86       339
#      samples avg       0.93      0.86      0.88       339
#
# SVM Confusion Matrix:
# KNN - Cross-Validation Accuracy: nan ± nan
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 33
#      27 print(
#      28     f"{model_name} - Cross-Validation Accuracy: {np.mean(scores):.4f} ± {np.std(scores):.4f}"
#      29 )
#      31 wrapped_model.fit(X_train, y_train_multi)
# ---> 33 y_pred_multi = wrapped_model.predict(X_test)
#      35 accuracy = accuracy_score(y_test_multi, y_pred_multi)
#      36 print(f"{model_name} Final Accuracy:", accuracy)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\skmultilearn\problem_transform\br.py:181, in BinaryRelevance.predict(self, X)
#     167 def predict(self, X):
#     168     """Predict labels for X
#     169
#     170     Parameters
#    (...)
#     178         binary indicator matrix with label assignments
#     179     """
#     180     predictions = [self._ensure_multi_label_from_single_class(
# --> 181         self.classifiers_[label].predict(self._ensure_input_format(X)))
#     182         for label in range(self.model_count_)]
#     184     return hstack(predictions)
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:259, in KNeighborsClassifier.predict(self, X)
#     255 if self.weights == "uniform":
#     256     if self._fit_method == "brute" and ArgKminClassMode.is_usable_for(
#     257         X, self._fit_X, self.metric
#     258     ):
# --> 259         probabilities = self.predict_proba(X)
#     260         if self.outputs_2d_:
#     261             return np.stack(
#     262                 [
#     263                     self.classes_[idx][np.argmax(probas, axis=1)]
#    (...)
#     266                 axis=1,
#     267             )
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:366, in KNeighborsClassifier.predict_proba(self, X)
#     362         return probabilities
#     364     # In that case, we do not need the distances to perform
#     365     # the weighting so we do not compute them.
# --> 366     neigh_ind = self.kneighbors(X, return_distance=False)
#     367     neigh_dist = None
#     368 else:
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\neighbors\_base.py:850, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     843 use_pairwise_distances_reductions = (
#     844     self._fit_method == "brute"
#     845     and ArgKmin.is_usable_for(
#     846         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     847     )
#     848 )
#     849 if use_pairwise_distances_reductions:
# --> 850     results = ArgKmin.compute(
#     851         X=X,
#     852         Y=self._fit_X,
#     853         k=n_neighbors,
#     854         metric=self.effective_metric_,
#     855         metric_kwargs=self.effective_metric_params_,
#     856         strategy="auto",
#     857         return_distance=return_distance,
#     858     )
#     860 elif (
#     861     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     862 ):
#     863     results = _kneighbors_from_graph(
#     864         X, n_neighbors=n_neighbors, return_distance=return_distance
#     865     )
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py:278, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     197 """Compute the argkmin reduction.
#     198
#     199 Parameters
#    (...)
#     275 returns.
#     276 """
#     277 if X.dtype == Y.dtype == np.float64:
# --> 278     return ArgKmin64.compute(
#     279         X=X,
#     280         Y=Y,
#     281         k=k,
#     282         metric=metric,
#     283         chunk_size=chunk_size,
#     284         metric_kwargs=metric_kwargs,
#     285         strategy=strategy,
#     286         return_distance=return_distance,
#     287     )
#     289 if X.dtype == Y.dtype == np.float32:
#     290     return ArgKmin32.compute(
#     291         X=X,
#     292         Y=Y,
#    (...)
#     298         return_distance=return_distance,
#     299     )
#
# File sklearn\\metrics\\_pairwise_distances_reduction\\_argkmin.pyx:90, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute()
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\utils\fixes.py:94, in threadpool_limits(limits, user_api)
#      92     return controller.limit(limits=limits, user_api=user_api)
#      93 else:
# ---> 94     return threadpoolctl.threadpool_limits(limits=limits, user_api=user_api)
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:171, in threadpool_limits.__init__(self, limits, user_api)
#     167 def __init__(self, limits=None, user_api=None):
#     168     self._limits, self._user_api, self._prefixes = \
#     169         self._check_params(limits, user_api)
# --> 171     self._original_info = self._set_threadpool_limits()
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:268, in threadpool_limits._set_threadpool_limits(self)
#     265 if self._limits is None:
#     266     return None
# --> 268 modules = _ThreadpoolInfo(prefixes=self._prefixes,
#     269                           user_api=self._user_api)
#     270 for module in modules:
#     271     # self._limits is a dict {key: num_threads} where key is either
#     272     # a prefix or a user_api. If a module matches both, the limit
#     273     # corresponding to the prefix is chosed.
#     274     if module.prefix in self._limits:
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:340, in _ThreadpoolInfo.__init__(self, user_api, prefixes, modules)
#     337     self.user_api = [] if user_api is None else user_api
#     339     self.modules = []
# --> 340     self._load_modules()
#     341     self._warn_if_incompatible_openmp()
#     342 else:
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:373, in _ThreadpoolInfo._load_modules(self)
#     371     self._find_modules_with_dyld()
#     372 elif sys.platform == "win32":
# --> 373     self._find_modules_with_enum_process_module_ex()
#     374 else:
#     375     self._find_modules_with_dl_iterate_phdr()
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:485, in _ThreadpoolInfo._find_modules_with_enum_process_module_ex(self)
#     482         filepath = buf.value
#     484         # Store the module if it is supported and selected
# --> 485         self._make_module_from_path(filepath)
#     486 finally:
#     487     kernel_32.CloseHandle(h_process)
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:515, in _ThreadpoolInfo._make_module_from_path(self, filepath)
#     513 if prefix in self.prefixes or user_api in self.user_api:
#     514     module_class = globals()[module_class]
# --> 515     module = module_class(filepath, prefix, user_api, internal_api)
#     516     self.modules.append(module)
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:606, in _Module.__init__(self, filepath, prefix, user_api, internal_api)
#     604 self.internal_api = internal_api
#     605 self._dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
# --> 606 self.version = self.get_version()
#     607 self.num_threads = self.get_num_threads()
#     608 self._get_extra_info()
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:646, in _OpenBLASModule.get_version(self)
#     643 get_config = getattr(self._dynlib, "openblas_get_config",
#     644                      lambda: None)
#     645 get_config.restype = ctypes.c_char_p
# --> 646 config = get_config().split()
#     647 if config[0] == b"OpenBLAS":
#     648     return config[1].decode("utf-8")
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
from scipy.sparse import csr_matrix
y_pred_test = {}
for model_name, model in models.items():
    wrapped_model = BinaryRelevance(model)
    wrapped_model.fit(X_train, y_train_multi)
    y_pred_test[model_name] = wrapped_model.predict(
        
    )

for model_name, y_pred in y_pred_test.items():
    print(f"\n{model_name} Predictions:\n")
    dense_array = y_pred.toarray()
    print(dense_array)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 6
#       4     wrapped_model = BinaryRelevance(model)
#       5     wrapped_model.fit(X_train, y_train_multi)
# ----> 6     y_pred_test[model_name] = wrapped_model.predict(X_test)
#       8 for model_name, y_pred in y_pred_test.items():
#       9     print(f"\n{model_name} Predictions:\n")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\skmultilearn\problem_transform\br.py:181, in BinaryRelevance.predict(self, X)
#     167 def predict(self, X):
#     168     """Predict labels for X
#     169
#     170     Parameters
#    (...)
#     178         binary indicator matrix with label assignments
#     179     """
#     180     predictions = [self._ensure_multi_label_from_single_class(
# --> 181         self.classifiers_[label].predict(self._ensure_input_format(X)))
#     182         for label in range(self.model_count_)]
#     184     return hstack(predictions)
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:259, in KNeighborsClassifier.predict(self, X)
#     255 if self.weights == "uniform":
#     256     if self._fit_method == "brute" and ArgKminClassMode.is_usable_for(
#     257         X, self._fit_X, self.metric
#     258     ):
# --> 259         probabilities = self.predict_proba(X)
#     260         if self.outputs_2d_:
#     261             return np.stack(
#     262                 [
#     263                     self.classes_[idx][np.argmax(probas, axis=1)]
#    (...)
#     266                 axis=1,
#     267             )
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:366, in KNeighborsClassifier.predict_proba(self, X)
#     362         return probabilities
#     364     # In that case, we do not need the distances to perform
#     365     # the weighting so we do not compute them.
# --> 366     neigh_ind = self.kneighbors(X, return_distance=False)
#     367     neigh_dist = None
#     368 else:
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\neighbors\_base.py:850, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     843 use_pairwise_distances_reductions = (
#     844     self._fit_method == "brute"
#     845     and ArgKmin.is_usable_for(
#     846         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     847     )
#     848 )
#     849 if use_pairwise_distances_reductions:
# --> 850     results = ArgKmin.compute(
#     851         X=X,
#     852         Y=self._fit_X,
#     853         k=n_neighbors,
#     854         metric=self.effective_metric_,
#     855         metric_kwargs=self.effective_metric_params_,
#     856         strategy="auto",
#     857         return_distance=return_distance,
#     858     )
#     860 elif (
#     861     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     862 ):
#     863     results = _kneighbors_from_graph(
#     864         X, n_neighbors=n_neighbors, return_distance=return_distance
#     865     )
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py:278, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     197 """Compute the argkmin reduction.
#     198
#     199 Parameters
#    (...)
#     275 returns.
#     276 """
#     277 if X.dtype == Y.dtype == np.float64:
# --> 278     return ArgKmin64.compute(
#     279         X=X,
#     280         Y=Y,
#     281         k=k,
#     282         metric=metric,
#     283         chunk_size=chunk_size,
#     284         metric_kwargs=metric_kwargs,
#     285         strategy=strategy,
#     286         return_distance=return_distance,
#     287     )
#     289 if X.dtype == Y.dtype == np.float32:
#     290     return ArgKmin32.compute(
#     291         X=X,
#     292         Y=Y,
#    (...)
#     298         return_distance=return_distance,
#     299     )
#
# File sklearn\\metrics\\_pairwise_distances_reduction\\_argkmin.pyx:90, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute()
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\utils\fixes.py:94, in threadpool_limits(limits, user_api)
#      92     return controller.limit(limits=limits, user_api=user_api)
#      93 else:
# ---> 94     return threadpoolctl.threadpool_limits(limits=limits, user_api=user_api)
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:171, in threadpool_limits.__init__(self, limits, user_api)
#     167 def __init__(self, limits=None, user_api=None):
#     168     self._limits, self._user_api, self._prefixes = \
#     169         self._check_params(limits, user_api)
# --> 171     self._original_info = self._set_threadpool_limits()
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:268, in threadpool_limits._set_threadpool_limits(self)
#     265 if self._limits is None:
#     266     return None
# --> 268 modules = _ThreadpoolInfo(prefixes=self._prefixes,
#     269                           user_api=self._user_api)
#     270 for module in modules:
#     271     # self._limits is a dict {key: num_threads} where key is either
#     272     # a prefix or a user_api. If a module matches both, the limit
#     273     # corresponding to the prefix is chosed.
#     274     if module.prefix in self._limits:
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:340, in _ThreadpoolInfo.__init__(self, user_api, prefixes, modules)
#     337     self.user_api = [] if user_api is None else user_api
#     339     self.modules = []
# --> 340     self._load_modules()
#     341     self._warn_if_incompatible_openmp()
#     342 else:
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:373, in _ThreadpoolInfo._load_modules(self)
#     371     self._find_modules_with_dyld()
#     372 elif sys.platform == "win32":
# --> 373     self._find_modules_with_enum_process_module_ex()
#     374 else:
#     375     self._find_modules_with_dl_iterate_phdr()
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:485, in _ThreadpoolInfo._find_modules_with_enum_process_module_ex(self)
#     482         filepath = buf.value
#     484         # Store the module if it is supported and selected
# --> 485         self._make_module_from_path(filepath)
#     486 finally:
#     487     kernel_32.CloseHandle(h_process)
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:515, in _ThreadpoolInfo._make_module_from_path(self, filepath)
#     513 if prefix in self.prefixes or user_api in self.user_api:
#     514     module_class = globals()[module_class]
# --> 515     module = module_class(filepath, prefix, user_api, internal_api)
#     516     self.modules.append(module)
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:606, in _Module.__init__(self, filepath, prefix, user_api, internal_api)
#     604 self.internal_api = internal_api
#     605 self._dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
# --> 606 self.version = self.get_version()
#     607 self.num_threads = self.get_num_threads()
#     608 self._get_extra_info()
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\threadpoolctl.py:646, in _OpenBLASModule.get_version(self)
#     643 get_config = getattr(self._dynlib, "openblas_get_config",
#     644                      lambda: None)
#     645 get_config.restype = ctypes.c_char_p
# --> 646 config = get_config().split()
#     647 if config[0] == b"OpenBLAS":
#     648     return config[1].decode("utf-8")
#
# AttributeError: 'NoneType' object has no attribute 'split'
